# %% [markdown]
# # Initalization

# %%
from glob import glob
import os

import gensim
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE

# %%
from colour import Color

# %%
def get_color_gradient(num_colors, start_color, end_color):
    """
    Given a number of steps to generate a color list over, return a list of hex-valued colors from start_color to end_color in num_colors steps.
    Useful for visualizing data that is continuous by shading each unique value of that data by a color that can correspond to its value.
    Example usage:
        get_color_gradient(5, colour.Color('white'), colour.Color('green'))
    
    :param num_colors: int
        The number of colors to generate a gradient for
    :param start_color: colour.Color object
        The color to start from
    :param end_color: colour.Color object
        The color to end at
        
    :return: list
        List of num_colors hex-valued colors from start_color to end_color, using the colour.Color.range_to method
    """
    
    return [c.get_hex_l() for c in start_color.range_to(end_color, steps=num_colors)]

# %% [markdown]
# ## Load data

# %%
cwd = os.getcwd()
data_dir = os.path.join(cwd, '../data/stanfordSentimentTreebank/')

# %%
data_dir
# Out:
# '/Users/dstone/projects/machine_learning/nlp/notebooks/../data/stanfordSentimentTreebank/'

# %%
dict_of_df = {}
for file in glob('{}/*.txt'.format(data_dir)):
    if 'readme' in file.lower():
        continue
    name = file.split('/')[-1].split('.')[0]
    dict_of_df[name] = pd.read_table(file, header=None)

# %%
dict_of_df = {}
# their data is in a different format for each txt file, so jeeze we have to parse each individually
# get phrases 
dict_of_df['phrases'] = pd.read_table('{}/dictionary.txt'.format(data_dir), header=None, delimiter='|', names=['phrase', 'phrase_id'], index_col=['phrase_id'])
dict_of_df['sentiments'] = pd.read_table('{}/sentiment_labels.txt'.format(data_dir), header=1, delimiter='|', names=['phrase_id', 'score'], index_col=['phrase_id'])

# now the sentences
dict_of_df['sentences'] = pd.read_table('{}/datasetSentences.txt'.format(data_dir), header=1, delimiter='\t', names=['sentence_id', 'sentence'])#, index_col=['sentence_id'])
dict_of_df['split'] = pd.read_table('{}/datasetSplit.txt'.format(data_dir), header=1, delimiter=',', names=['sentence_id', 'split'])#, index_col=['sentence_id'])

# now match phrases to sentences. I don't know how to use the parser yet. Do this later

# %%
# match the content of the phrases to their sentiment scores
df_phrases = dict_of_df['phrases'].merge(dict_of_df['sentiments'], left_index=True, right_index=True)

# %%
dict_of_df['sentences'].head()
# Out:
#    sentence_id                                           sentence
# 0            2  The gorgeously elaborate continuation of `` Th...
# 1            3                     Effective but too-tepid biopic
# 2            4  If you sometimes like to go to the movies to h...
# 3            5  Emerges as something rare , an issue movie tha...
# 4            6  The film provides some great insight into the ...

# %%
# merge sentences to phrases, forget parsing (this loses a lot of data)
# we need the sentence ID because this gives us the split to use for training/dev/test
df_phrases.merge(dict_of_df['sentences'], left_on='phrase', right_on='sentence')#.drop('sentence', axis=1)
# Out:
#                                                   phrase     score  \
# 0      , The Sum of All Fears is simply a well-made a...  0.888890
# 1                           , `` They 're out there ! ''  0.611110
# 2      , is a temporal inquiry that shoulders its phi...  0.694440
# 3           - I also wanted a little alien as a friend !  0.694440
# 4      - West Coast rap wars , this modern mob music ...  0.763890
# 5                      - greaseballs mob action-comedy .  0.361110
# 6      - spy action flick with Antonio Banderas and L...  0.166670
# 7      - style cross-country adventure ... it has spo...  0.708330
# 8                        -- but certainly hard to hate .  0.611110
# 9      -- but it makes for one of the most purely enj...  0.819440
# 10     -- is a crime that should be punishable by cha...  0.277780
# 11     -- that the ` true story ' by which All the Qu...  0.222220
# 12           -- was a fad that had long since vanished .  0.416670
# 13                 -LRB- A -RRB- rare , beautiful film .  0.958330
# 14     -LRB- Drumline -RRB- is entertaining for what ...  0.736110
# 15     -LRB- Schweiger is -RRB- talented and terribly...  0.777780
# 16     -LRB- Wendigo is -RRB- why we go to the cinema...  0.652780
# 17     ... Blade II is more enjoyable than the origin...  0.916670
# 18     ... Blade II is still top-heavy with blazing g...  0.166670
# 19     ... Brian De Palma is utterly mad : cinema mad...  0.583330
# 20     ... Designed to provide a mix of smiles and te...  0.222220
# 21     ... Despite lagging near the finish line , the...  0.777780
# 22     ... Hudlin is stuck trying to light a fire wit...  0.375000
# 23     ... Ice Age treads predictably along familiar ...  0.430560
# 24      ... In this incarnation its fizz is infectious .  0.847220
# 25     ... Jones , despite a definitely distinctive s...  0.555560
# 26     ... Liotta is put in an impossible spot becaus...  0.277780
# 27     ... Mafia , rap stars and hood rats butt their...  0.652780
# 28     ... Myers has turned his franchise into the mo...  0.500000
# 29     ... Pray does n't have a passion for the mater...  0.305560
# ...                                                  ...       ...
# 11255                              than ` Magnifique ' .  0.500000
# 11256  that it 'll probably be the best and most matu...  0.666670
# 11257                                       that works .  0.666670
# 11258  the Venezuelans say things like `` si , pretty...  0.402780
# 11259  the film belongs to the marvelous Verdu , a se...  0.722220
# 11260  the film does n't sustain its initial promise ...  0.347220
# 11261  the film never rises above a conventional , tw...  0.277780
# 11262  the film tunes into a grief that could lead a ...  0.652780
# 11263  the phone rings and a voice tells you you 've ...  0.555560
# 11264  the plot is so amusingly contrived and outland...  0.472220
# 11265  the story itself is uninteresting , and the so...  0.083333
# 11266                                there is truth here  0.666670
# 11267  this film is not a love letter for the slain r...  0.500000
# 11268  to be more engaging on an emotional level , fu...  0.402780
# 11269  too many scenarios in which the hero might hav...  0.180560
# 11270  turns a potentially interesting idea into an e...  0.125000
# 11271                       under-rehearsed and lifeless  0.166670
# 11272       unpretentious , charming , quirky , original  0.916670
# 11273  very solid , very watchable first feature for ...  0.777780
# 11274  waydowntown manages to nail the spirit-crushin...  0.666670
# 11275  waydowntown may not be an important movie , or...  0.722220
# 11276                              well worth the time .  0.819440
# 11277  what really makes it special is that it pulls ...  1.000000
# 11278  when Leguizamo finally plugged an irritating c...  0.250000
# 11279  will be far more interesting to the Soderbergh...  0.555560
# 11280  wo n't be placed in the pantheon of the best o...  0.847220
# 11281  works , it 's thanks to Huston 's revelatory p...  0.763890
# 11282  works on the whodunit level as its larger them...  0.361110
# 11283  would make an excellent companion piece to the...  0.750000
# 11284  would seem to have a lock on the title of ugli...  0.097222
#
#        sentence_id                                           sentence
# 0             4860  , The Sum of All Fears is simply a well-made a...
# 1             7251                       , `` They 're out there ! ''
# 2             5477  , is a temporal inquiry that shoulders its phi...
# 3             5576       - I also wanted a little alien as a friend !
# 4             2338  - West Coast rap wars , this modern mob music ...
# 5             7166                  - greaseballs mob action-comedy .
# 6            11305  - spy action flick with Antonio Banderas and L...
# 7            11409  - style cross-country adventure ... it has spo...
# 8             7163                    -- but certainly hard to hate .
# 9             2732  -- but it makes for one of the most purely enj...
# 10            6580  -- is a crime that should be punishable by cha...
# 11            7778  -- that the ` true story ' by which All the Qu...
# 12           10865        -- was a fad that had long since vanished .
# 13           11623              -LRB- A -RRB- rare , beautiful film .
# 14             224  -LRB- Drumline -RRB- is entertaining for what ...
# 15             145  -LRB- Schweiger is -RRB- talented and terribly...
# 16              14  -LRB- Wendigo is -RRB- why we go to the cinema...
# 17             961  ... Blade II is more enjoyable than the origin...
# 18           11495  ... Blade II is still top-heavy with blazing g...
# 19            1550  ... Brian De Palma is utterly mad : cinema mad...
# 20            7900  ... Designed to provide a mix of smiles and te...
# 21            3019  ... Despite lagging near the finish line , the...
# 22            7929  ... Hudlin is stuck trying to light a fire wit...
# 23            5877  ... Ice Age treads predictably along familiar ...
# 24             148   ... In this incarnation its fizz is infectious .
# 25            5998  ... Jones , despite a definitely distinctive s...
# 26            9890  ... Liotta is put in an impossible spot becaus...
# 27            1262  ... Mafia , rap stars and hood rats butt their...
# 28            4879  ... Myers has turned his franchise into the mo...
# 29            2950  ... Pray does n't have a passion for the mater...
# ...            ...                                                ...
# 11255         9142                              than ` Magnifique ' .
# 11256         1734  that it 'll probably be the best and most matu...
# 11257        11566                                       that works .
# 11258        11504  the Venezuelans say things like `` si , pretty...
# 11259         3727  the film belongs to the marvelous Verdu , a se...
# 11260         3592  the film does n't sustain its initial promise ...
# 11261         9777  the film never rises above a conventional , tw...
# 11262         1250  the film tunes into a grief that could lead a ...
# 11263         6471  the phone rings and a voice tells you you 've ...
# 11264          782  the plot is so amusingly contrived and outland...
# 11265         8546  the story itself is uninteresting , and the so...
# 11266         1832                                there is truth here
# 11267         2902  this film is not a love letter for the slain r...
# 11268         5309  to be more engaging on an emotional level , fu...
# 11269         9247  too many scenarios in which the hero might hav...
# 11270        10194  turns a potentially interesting idea into an e...
# 11271        11783                       under-rehearsed and lifeless
# 11272         5568       unpretentious , charming , quirky , original
# 11273          643  very solid , very watchable first feature for ...
# 11274         5594  waydowntown manages to nail the spirit-crushin...
# 11275         6669  waydowntown may not be an important movie , or...
# 11276          949                              well worth the time .
# 11277         1240  what really makes it special is that it pulls ...
# 11278         7428  when Leguizamo finally plugged an irritating c...
# 11279         9339  will be far more interesting to the Soderbergh...
# 11280         4970  wo n't be placed in the pantheon of the best o...
# 11281         3648  works , it 's thanks to Huston 's revelatory p...
# 11282         6533  works on the whodunit level as its larger them...
# 11283         2543  would make an excellent companion piece to the...
# 11284         8730  would seem to have a lock on the title of ugli...
#
# [11285 rows x 4 columns]

# %%
gensim.

# %% [markdown]
# # t-SNE clustering with word2vec by sentiment

# %%
# Need to embed the words first

# %%
model = gensim.models.Word2Vec(X, size=100)
w2v = dict(zip(model.wv.index2word, model.wv.syn0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-7b642e8ac250> in <module>()
# ----> 1 model = gensim.models.Word2Vec(X, size=100)
#       2 w2v = dict(zip(model.wv.index2word, model.wv.syn0))
#
# NameError: name 'X' is not defined
